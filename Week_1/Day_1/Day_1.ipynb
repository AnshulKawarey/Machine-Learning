# %% [markdown]
# # **Day 1 – What is Machine Learning?**
#
# #### Welcome to the first day of the course
# ## Machine Learning with Python: From Basics to Applications
#
# ---
#
# # Learning Objectives
# By the end of this lesson, you should be able to:
# - Define what Machine Learning is
# - Distinguish between types of Machine Learning
# - Understand the difference between Classification and Regression
# - See real-world use cases of ML

# %% [markdown]
# # What is Machine Learning?
#
# **Machine Learning (ML)** is a subset of Artificial Intelligence (AI) that allows systems to learn and make predictions or decisions based on data.
#
# ### Traditional Programming vs ML
# - **Traditional Programming**: Data + Rules → Output
# - **Machine Learning**: Data + Output → Algorithm learns rules → Predicts Output

# %% [markdown]
# # Types of Machine Learning

# %% [markdown]
# ![supervised (2).png](attachment:d32e4092-a1d2-4ff0-b142-50c3bba9ea08.png)
# ![image.png](attachment:b9a061e6-06fd-466c-b607-c9d94c50baa0.png)
# ![image.png](attachment:99811dd8-2731-4bdd-ba60-18d623094485.png)

# %% [markdown]
# ## Classification vs Regression
#
# | Type | Output Type | Example |
# |------|-------------|---------|
# | **Classification** | Categorical | Predicting type of a species |
# | **Regression** | Continuous | Predicting house prices |
#
# ## Classification
# ![image.png](attachment:225b2bd6-755a-4798-85aa-17d27df412d3.png)
#
# ## Regression
# ![image.png](attachment:d3e6811e-e88b-4563-b545-d9fd8937db28.png)

# %% [markdown]
# # Code Demo: Classification Dataset (Iris)
# ### Let's load and explore a classification dataset using `scikit-learn`. The **Iris** dataset contains features of flowers and labels representing species.

# %%
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris = load_iris()
df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
df_iris['target'] = iris.target
df_iris['species'] = df_iris['target'].apply(lambda x: iris.target_names[x])

sns.scatterplot(data=df_iris, x='petal length (cm)', y='petal width (cm)', hue='species', palette='Set1')
plt.title("Iris Dataset – Sepal Length vs Width")
plt.show()

# %% [markdown]
# ![image.png](attachment:35bba281-8684-4221-8f8e-5c645d6d9e2b.png) ![image.png](attachment:afc8f299-92c0-483c-9130-21bba3b797f8.png)

# %% [markdown]
# # Code Demo: Regression Dataset (Height vs Weight)
# ### Now let's see a regression dataset where the goal is to predict weight based on the height.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression

np.random.seed(1)
heights = np.random.normal(165, 10, 100) 
weights = heights * 0.45 + np.random.normal(0, 5, 100)

df = pd.DataFrame({'Height (cm)': heights, 'Weight (kg)': weights})

model = LinearRegression()
model.fit(df[['Height (cm)']], df['Weight (kg)'])
df['Predicted Weight'] = model.predict(df[['Height (cm)']])

# Plot with regression line
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Height (cm)', y='Weight (kg)', label="Actual", alpha=0.6)
sns.lineplot(data=df, x='Height (cm)', y='Predicted Weight', color='red', label="Regression Line")
plt.title("Height vs Weight – Linear Regression Fit")
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# # Real-World ML Applications
#
# - **Netflix**: Recommending shows
# - **Google Maps**: Predicting traffic
# - **Medical field**: Disease diagnosis
# - **Banking**: Fraud detection

# %% [markdown]
# # Summary
# - ML is about learning from data to make predictions.
# - There are 3 main types: Supervised, Unsupervised, and Reinforcement.
# - Classification → predict categories; Regression → predict numbers.
#
# ---
#
# ### Next up: Day 2 – Python Refresher: NumPy and Pandas
